# %% [markdown]
# <a href="https://colab.research.google.com/github/vitorrobertogq/Batalha-naval-JAVA/blob/main/desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Configuraçao do Ambiente (ferramentas,base de dados,testes)

# %%
#Ferramentas utilizadas
import pandas as pd #leitura
import matplotlib.pyplot as plt #graficos
import ast #array em formato de string para formato de array normal
from geopy.geocoders import Nominatim #pegar coordenadas
import folium
from unidecode import unidecode
from IPython.display import display

# %%
#Bases de dados importadas
dados_ratings = pd.read_csv('desafio_ratings.csv',sep=';')
dados_details = pd.read_csv('desafio_details.csv',sep=';')

# %%
#Teste ratings
dados_ratings.head()
# Out:
#    Unnamed: 0  hotel_id                                        hotel_name  \
# 0           2  10966118        Casa em lindo cond. a 5min da praia PEV105
# 1           5  10959776     Apartamentos no Jardim Goiás Goiânia/GO - THO
# 2           6  10949139      Casa triplex em condomínio Floripa-SC ALI024
# 3           9  10948439     Apto com piscina no centro de Floripa PCE0406
# 4          10  10943450  Apto espaçoso na beira do lago em Ilhéus ARS0169
#
#                                                  url  Comodidades  Limpeza  \
# 0  https://www.booking.com/hotel/br/casa-em-lindo...          NaN      NaN
# 1  https://www.booking.com/hotel/br/apartamentos-...          NaN      NaN
# 2  https://www.booking.com/hotel/br/casa-triplex-...          NaN      NaN
# 3  https://www.booking.com/hotel/br/apto-com-pisc...          NaN      NaN
# 4  https://www.booking.com/hotel/br/apto-espacoso...          NaN      NaN
#
#    Conforto  Custo-benefício  Localização  Total  WiFi gratuito  \
# 0       NaN              NaN          NaN    NaN            NaN
# 1       NaN              NaN          NaN    NaN            NaN
# 2       NaN              NaN          NaN    NaN            NaN
# 3       NaN              NaN          NaN    NaN            NaN
# 4       NaN              NaN          NaN    NaN            NaN
#
#    number_of_ratings
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
#Teste details
dados_details.head()
# Out:
#    Unnamed: 0  hotel_id     room_id  \
# 0           0  10966441  1096644102
# 1           1  10966258  1096625802
# 2           2  10966118  1096611801
# 3           3  10961514  1096151402
# 4           4  10960702  1096070202
#
#                                          hotel_name        city_name  \
# 0  Apto belo e com churrasqueira na varanda VIC0203    Florianópolis
# 1           Chalés encantadores em Urubici/SC - PAR          Urubici
# 2        Casa em lindo cond. a 5min da praia PEV105          Ubatuba
# 3          Studio a 2min da UFSC Floripa-SC SSG0304    Florianópolis
# 4   MGI - Apartamentos proximos da praia do Tororão  Arraial d'Ajuda
#
#   accommodation_type          room_name  room_surface_in_m2  \
# 0          apartment        Apartamento                96.0
# 1          apartment            Bangalô                65.0
# 2       holiday_home  Casa de 3 Quartos               220.0
# 3          apartment        Apartamento                51.0
# 4          apartment       Villa Deluxe               130.0
#
#                                      room_facilities
# 0  ['Taças de vinho', 'Secadora de roupas', 'Guar...
# 1  ['Banheiro privativo', 'Geladeira', 'TV', 'Sec...
# 2  ['Taças de vinho', 'Cozinha', 'Vaso sanitário'...
# 3  ['Toalhas', 'Sofá-cama', 'Fogão', 'Chuveiro', ...
# 4  ['Guarda-roupa ou armário', 'Área para refeiçõ...

# %% [markdown]
# Análise 1 - Cidades em ordem crescente de número de listings (anúncio ou oferta de uma propriedade)

# %%
#Para isso vamos separar os valores de interesseas duplicações de um mesmo imovel (variados quartos possuem um unico anúncio)
#e contar quantas vezes uma cidade aparece,o que resulta no número de imoveis por cidade
dados_listings = dados_details.loc[:,('hotel_id','city_name')].drop_duplicates()
dados_listings_ordenados = dados_listings['city_name'].value_counts(ascending=True).reset_index()
dados_listings_ordenados
# Out:
#                   index  city_name
# 0              São José          1
# 1         Águas Brancas          1
# 2           Hidrolândia          1
# 3   Santa Cruz Cabrália          1
# 4            Taguatinga          1
# 5          Caldas Novas          1
# 6            Anitápolis          1
# 7              Camboriú          1
# 8         Praia do Rosa          1
# 9           Pirenópolis          1
# 10           Meia Praia          1
# 11             Bertioga          1
# 12       Angra dos Reis          2
# 13             Trancoso          2
# 14         Águas Claras          2
# 15               Maceió          2
# 16              Urubici          3
# 17           Petrópolis          3
# 18             Brasília          3
# 19               Ilhéus          4
# 20               Búzios          5
# 21             Garopaba          6
# 22      Poços de Caldas          8
# 23      Arraial d'Ajuda          9
# 24               Canela          9
# 25     Campos do Jordão         10
# 26           Porto Belo         10
# 27               Itajaí         11
# 28              Ubatuba         12
# 29             Imbituba         13
# 30         Porto Seguro         13
# 31              Gramado         15
# 32            Cabo Frio         16
# 33         Porto Alegre         18
# 34              Itapema         22
# 35            Bombinhas         29
# 36              Goiânia         29
# 37   Balneário Camboriú         37
# 38        Florianópolis        425

# %% [markdown]
# Análise 2- Cidades em ordem decrescente de metros quadrados

# %%
#Para isso separar os dados em interesse e depois vamos agrupa-los em cidades e somar todos os m2 por meio da funcao 'sum()'
dados_m2 = dados_details.loc[:,('city_name','room_surface_in_m2')]
dados_m2_soma = dados_m2.groupby('city_name').sum().sort_values(by='room_surface_in_m2',ascending=False).reset_index()
dados_m2_soma
# Out:
#               city_name  room_surface_in_m2
# 0         Florianópolis            49473.22
# 1               Goiânia             5342.00
# 2             Bombinhas             4247.00
# 3    Balneário Camboriú             4023.80
# 4               Itapema             2553.80
# 5      Campos do Jordão             2495.00
# 6          Porto Seguro             2019.26
# 7             Cabo Frio             1687.00
# 8               Ubatuba             1476.00
# 9                Itajaí             1368.37
# 10             Imbituba             1368.00
# 11           Porto Belo             1261.00
# 12               Canela              924.00
# 13           Anitápolis              910.00
# 14              Gramado              879.50
# 15               Búzios              874.00
# 16      Arraial d'Ajuda              868.00
# 17             Garopaba              796.00
# 18         Porto Alegre              682.00
# 19             Trancoso              384.00
# 20           Petrópolis              382.00
# 21               Ilhéus              369.74
# 22  Santa Cruz Cabrália              320.00
# 23       Angra dos Reis              320.00
# 24      Poços de Caldas              297.00
# 25             Bertioga              156.00
# 26          Pirenópolis              130.00
# 27              Urubici              125.00
# 28             Brasília               89.00
# 29               Maceió               83.00
# 30           Meia Praia               70.00
# 31             São José               60.00
# 32         Águas Claras               58.00
# 33         Caldas Novas               50.00
# 34           Taguatinga               50.00
# 35             Camboriú               43.00
# 36        Águas Brancas               30.00
# 37          Hidrolândia                0.00
# 38        Praia do Rosa                0.00

# %% [markdown]
# Análise 3 - Quais cidades têm mais avaliações?

# %%
#Para isso vamos usar 2 dados em tabelas distintas já que eles estão separados em 2 bancos de dados diferentes
#Vamos usar da desafio_ratings = hotel_id,number_of_ratings e da desafio_details = hotel_id,city_name
#e concilia-lás para termos um dataFrame que junte as cidades aos números de avaliação

dados_hotel_cidade = dados_details.loc[:,('hotel_id','city_name')].drop_duplicates()
dados_hotel_cidade
# Out:
#       hotel_id        city_name
# 0     10966441    Florianópolis
# 1     10966258          Urubici
# 2     10966118          Ubatuba
# 3     10961514    Florianópolis
# 4     10960702  Arraial d'Ajuda
# ...        ...              ...
# 1153   4584108    Florianópolis
# 1191   4549889    Florianópolis
# 1245   4504984    Florianópolis
# 1304   2966211    Florianópolis
# 1306    359731        Bombinhas
#
# [730 rows x 2 columns]

# %%
dados_hotel_ratings = dados_ratings.loc[:,('hotel_id','number_of_ratings')]
dados_hotel_ratings
# Out:
#      hotel_id  number_of_ratings
# 0    10966118                  0
# 1    10959776                  0
# 2    10949139                  0
# 3    10948439                  0
# 4    10943450                  0
# ..        ...                ...
# 708   4584108                633
# 709   4549889                305
# 710   4504984                446
# 711   2966211                 29
# 712    359731                 88
#
# [713 rows x 2 columns]

# %%
#Agora juntando as 2 com a função 'pd.merge()' com base no hotel_id e após isso agrupar por cidade e somar tudo pela função 'sum()'
dados_hotel_cidade_ratings = pd.merge(dados_hotel_cidade,dados_hotel_ratings,on='hotel_id')
dados_num_avaliacao = dados_hotel_cidade_ratings.loc[:,('city_name','number_of_ratings')].groupby('city_name').sum().sort_values(by='number_of_ratings',ascending=False)
dados_num_avaliacao
# Out:
#                      number_of_ratings
# city_name
# Florianópolis                     3264
# Campos do Jordão                   135
# Bombinhas                          128
# Anitápolis                          78
# Balneário Camboriú                  54
# Itajaí                              23
# Itapema                             19
# Goiânia                             19
# Gramado                             15
# Porto Belo                           8
# Petrópolis                           8
# Canela                               6
# São José                             6
# Porto Alegre                         5
# Ubatuba                              4
# Cabo Frio                            4
# Ilhéus                               3
# Garopaba                             3
# Poços de Caldas                      3
# Camboriú                             1
# Brasília                             1
# Urubici                              1
# Angra dos Reis                       1
# Taguatinga                           0
# Trancoso                             0
# Santa Cruz Cabrália                  0
# Praia do Rosa                        0
# Águas Brancas                        0
# Imbituba                             0
# Porto Seguro                         0
# Pirenópolis                          0
# Meia Praia                           0
# Maceió                               0
# Hidrolândia                          0
# Caldas Novas                         0
# Búzios                               0
# Bertioga                             0
# Arraial d'Ajuda                      0
# Águas Claras                         0

# %% [markdown]
# Análise 4 - Quais cidades têm a maior média de avaliações? E a menor média?

# %%
#Utiliza os dados encontrados anteriomente 'dados_hotel_cidade_ratings',agrupa-os novamente por cidade
#e em vez de somar tudo,calcula-se a media por meio da funcao 'mean()'
dados_media_avaliacao = dados_hotel_cidade_ratings.loc[:,('city_name','number_of_ratings')].groupby('city_name').mean().sort_values(by='number_of_ratings',ascending=False)
dados_media_avaliacao
# Out:
#                      number_of_ratings
# city_name
# Anitápolis                   78.000000
# Campos do Jordão             13.500000
# Florianópolis                 7.789976
# São José                      6.000000
# Bombinhas                     4.413793
# Petrópolis                    4.000000
# Itajaí                        2.300000
# Balneário Camboriú            1.542857
# Gramado                       1.071429
# Camboriú                      1.000000
# Itapema                       0.863636
# Porto Belo                    0.800000
# Goiânia                       0.760000
# Ilhéus                        0.750000
# Canela                        0.666667
# Angra dos Reis                0.500000
# Urubici                       0.500000
# Garopaba                      0.500000
# Poços de Caldas               0.375000
# Ubatuba                       0.363636
# Brasília                      0.333333
# Porto Alegre                  0.277778
# Cabo Frio                     0.250000
# Taguatinga                    0.000000
# Trancoso                      0.000000
# Santa Cruz Cabrália           0.000000
# Águas Brancas                 0.000000
# Praia do Rosa                 0.000000
# Imbituba                      0.000000
# Porto Seguro                  0.000000
# Pirenópolis                   0.000000
# Meia Praia                    0.000000
# Maceió                        0.000000
# Hidrolândia                   0.000000
# Caldas Novas                  0.000000
# Búzios                        0.000000
# Bertioga                      0.000000
# Arraial d'Ajuda               0.000000
# Águas Claras                  0.000000

# %% [markdown]
# Análise 5 - Existem correlações entre as características de um anúncio e a sua localização?

# %%
#Para essa vou verificar essa correlaçao vou analisar uma caracteristica que define demais a experiencia do cliente : tipo de locação

# %%
dados_tipo = dados_details.loc[:,('hotel_id','city_name','accommodation_type')].drop_duplicates()
dados_por_tipo = dados_tipo.loc[:,('city_name','accommodation_type')].value_counts().reset_index()
dados_por_tipo.rename(columns={0: 'count'}, inplace=True)
dados_por_tipo
# Out:
#              city_name accommodation_type  count
# 0        Florianópolis          apartment    348
# 1        Florianópolis       holiday_home     56
# 2   Balneário Camboriú          apartment     35
# 3              Goiânia          apartment     29
# 4              Itapema          apartment     21
# ..                 ...                ...    ...
# 63          Anitápolis             chalet      1
# 64         Hidrolândia       farm_holiday      1
# 65            Imbituba              lodge      1
# 66            Imbituba                inn      1
# 67             Gramado       holiday_home      1
#
# [68 rows x 3 columns]

# %%
# Supondo que seus dados estejam em um DataFrame chamado df
# Substitua df pelo nome real do seu DataFrame

# Crie um DataFrame com as colunas 'city_name', 'accommodation_type' e 'count'
dados_por_tipo = dados_por_tipo[['city_name', 'accommodation_type', 'count']].drop_duplicates()

# Crie uma tabela dinâmica para obter a contagem total por tipo de acomodação e cidade
accommodation_counts = pd.pivot_table(dados_por_tipo, values='count', index='city_name', columns='accommodation_type', fill_value=0)

# Adicione uma coluna indicando se há mais apartamentos do que a soma das outras locações
accommodation_counts['more_apartments_than_others'] = accommodation_counts['apartment'] > accommodation_counts.drop('apartment', axis=1).sum(axis=1)

# Exiba o resultado
accommodation_counts.reset_index(inplace=True)

# %%
#configurar o geolocalizador sem verificação SSL
geolocator = Nominatim(user_agent="my_geocoder", ssl_context=None)

#função para mapear a nota para uma cor
def map_nota_to_color(tipo):
    # Usei um gradiente de azul para verde para vermelho
    if not tipo:
        return 'blue'
    else:
        return 'red'

#função para manipular o nome da cidade
def format_city_name(city):

    #remover acentos e converter para minúsculas e adicionando brasil para diminuir erros relativos a localização
    formatted_city = unidecode(city).lower()+ '-brasil'

    #cidades que não condiziam com a localização encontrada e precisaram de uma ajuda na pesquisa
    if formatted_city == 'brasilia-brasil':
        formatted_city = 'brasilia-df-brasil'
    if formatted_city == 'sao jose-brasil':
        formatted_city = 'sao jose-sc-brasil'

    return formatted_city

#criar um mapa básico centrado em uma localização do brasil
mapa = folium.Map(location=[-15.7801, -47.9292], zoom_start=4)

#adicionar marcadores ao mapa
for index, row in accommodation_counts.iterrows():
    #manipular o nome da cidade antes de fazer a pesquisa
    formatted_city_name = format_city_name(row['city_name'])

    #obter as coordenadas a partir do nome da cidade
    location = geolocator.geocode(formatted_city_name, timeout=10)

    #verificar se a localização foi encontrada
    if location:
        #mapear a nota para a cor do ícone
        color = map_nota_to_color(row['more_apartments_than_others'])

        #criar marcador com popup contendo informações e cor ajustada
        folium.Marker(
            location=[location.latitude, location.longitude],
            popup=f"{row['city_name']}",
            icon=folium.Icon(color=color, icon='home')
        ).add_to(mapa)

#exibir o mapa no notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32a426df16f6108494ac67a0bf728a3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32a426df16f6108494ac67a0bf728a3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32a426df16f6108494ac67a0bf728a3b = L.map(
#                 &quot;map_32a426df16f6108494ac67a0bf728a3b&quot;,
#                 {
#                     center: [-15.7801, -47.9292],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f6c92372823ea4f6f9b429d75fcfc88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_32a426df16f6108494ac67a0bf728a3b);
#
#
#             var marker_303a748ffee7df2f6b04b023a142198d = L.marker(
#                 [-23.0063966, -44.316326],
#                 {}
#             ).addTo(map_32a426df16f6108494ac67a0bf728a3b);
#
#
#             var icon_90a7e12af4e2a7a49c430bb83fa49de3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_303a748ffee7df2f6b04b023a142198d.setIcon(icon_90a7e12af4e2a7a49c430bb83fa49de3);
#
#
#         var popup_3696f6d3292abe6507ec5fffdabd0caf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_342500c78949e3782fbb2c98aa666911 = $(`&lt;div id=&quot;html_342500c78949e3782fbb2c98aa666911&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angra dos Reis&lt;/div&gt;`)[0];
#                 popup_3696f6d3292abe6507ec5fffdabd0caf.setContent(html_342500c78949e3782fbb2c98aa666911);
#
#
#
#         marker_303a748ffee7df2f6b04b023a142198d.bindPopup(popup_3696f6d3292abe6507ec5fffdabd0caf)
#         ;
#
#
#
#
#             var marker_a443b22187cfaf1c8ad52e28aa417cb1 = L.marker(
#                 [-27.9041185, -49.1287395],
#                 {}
#             ).addTo(map_32a426df16f6108494ac67a0bf728a3b);
#
#
#             var icon_e67c9b878ad46f695dfdfe16f8b65f40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a443b22187cfaf1c8ad52e28aa417cb1.setIcon(icon_e67c9b878ad46f695dfdfe16f8b65f40);
#
#
#         var popup_d333de5371623d2d4be242a88034579b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_212ab91f899ddb530fb6529a76557edb = $(`&lt;div id=&quot;html_212ab91f899ddb530fb6529a76557edb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anitápolis&lt;/div&gt;`)[0];
#                 popup_d333de5371623d2d4be242a88034579b.setContent(html_212ab91f899ddb530fb6529a76557edb);
#
#
#
#         marker_a443b22187cfaf1c8ad52e28aa417cb1.bindPopup(popup_d333de5371623d2d4be242a88034579b)
#         ;
#
#
#
#
#             var marker_023098130da4f9e7f9f9dba89e6c550a = L.marker(
#                 [-16.484756, -39.07288],
#                 {}
#             ).addTo(map_32a426df16f6108494ac67a0bf728a3b);
#
#
#             var icon_b5d903faec9116490547a2a6728a0844 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_023098130da4f9e7f9f9dba89e6c550a.setIcon(icon_b5d903faec9116490547a2a6728a0844);
#
#
#         var popup_31f09a5350a42b87f64ca1bb38cd0bb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e938efdc644dd1ae29f5f9d0d9d9314e = $(`&lt;div id=&quot;html_e938efdc644dd1ae29f5f9d0d9d9314e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arraial d&#x27;Ajuda&lt;/div&gt;`)[0];
#                 popup_31f09a5350a42b87f64ca1bb38cd0bb0.setContent(html_e938efdc644dd1ae29f5f9d0d9d9314e);
#
#
#
#         marker_023098130da4f9e7f9f9dba89e6c550a.bindPopup(popup_31f09a5350a42b87f64ca1bb38cd0bb0)
#         ;
#
#
#
#
#             var marker_16efbc5be4b55610a0d2d95f1967d553 = L.marker(
#                 [-26.9924395, -48.6339782],
#                 {}
#             ).addTo(map_32a426df16f6108494ac67a0bf728a3b);
#
#
#             var icon_688d52bfbbb73a709f5e33b66e4283e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home

# %% [markdown]
# Análise 6 - Existem relações entre a nota do anúncio e os recursos disponíveis no imóvel?

# %%
#Para esse vamos precisar fazer a média de todos os recursos de cada imóvel (já que cada quarto possui recursos diferentes)
#e com a média de recursos de cada imóvel calcula a relação deles com a nota

def calcular_tamanho(lista_string):
    lista = ast.literal_eval(lista_string)
    return len(lista)

numeros_de_recursos = dados_details.loc[:,('hotel_id','room_facilities')]
numeros_de_recursos['num_of_facilities'] = numeros_de_recursos['room_facilities'].apply(calcular_tamanho)
numeros_de_recursos_media = numeros_de_recursos.loc[:,('hotel_id','num_of_facilities')].groupby('hotel_id').mean().reset_index()

# %%
#Agora ligar o hotel_id e a nota (apenas hoteis que possuem alguma avaliação)

dados_hotel_nota= dados_ratings.loc[:,('hotel_id','Total')]
dados_hotel_nota.dropna(inplace=True)
dados_hotel_nota
# Out:
#      hotel_id  Total
# 61   10812173   10.0
# 78   10792136   10.0
# 83   10790322   10.0
# 86   10779085   10.0
# 89   10778804   10.0
# ..        ...    ...
# 708   4584108    9.2
# 709   4549889    9.2
# 710   4504984    9.1
# 711   2966211    7.7
# 712    359731    8.7
#
# [300 rows x 2 columns]

# %%
#Agora por fim,juntar os 2 dados e calcular sua correlação

dados_recursos_nota = pd.merge(dados_hotel_nota,numeros_de_recursos_media,on='hotel_id')
correlacao = dados_recursos_nota.loc[:,('Total', 'num_of_facilities')].corr()
print(correlacao) #0.146964 = fraca
# Out:
#                       Total  num_of_facilities
# Total              1.000000           0.121698
# num_of_facilities  0.121698           1.000000

# %%
#vamos tentar observar isso de uma maneira mais visual, dividindo os hotel_id pela nota no caso(0-2,2-4,4-6,8-10) e usando a media de recursos como paramentro
#o que nos leva a uma observação mais clara que essa correlação é fraca de maneira mais visual

#definir as faixas de notas
faixas_notas = [0, 2, 4, 6, 8, 10]

#criar uma coluna 'faixa_notas' no DataFrame
dados_recursos_nota['faixa_notas'] = pd.cut(dados_recursos_nota['Total'], bins=faixas_notas, labels=[f'{i}-{i+2}' for i in range(0, 10, 2)])

#calcular a média de recursos para cada faixa de notas
media_recursos_por_faixa = dados_recursos_nota.groupby('faixa_notas')['num_of_facilities'].mean()

#plotar o gráfico de barras
media_recursos_por_faixa.plot(kind='bar', color='skyblue')
plt.title('Média de Recursos Normalizada por Faixa de Notas')
plt.xlabel('Faixa de Notas')
plt.ylabel('Média de Recursos (normalizada)')
plt.show()

# %%
#E agora testando com recursos especificos('Ar-condicionado')
def tem_recurso(lista_string):
    lista = ast.literal_eval(lista_string)
    if 'Ar-condicionado'in lista:
        return True
    else:
        return False

dados_tem_ar = dados_details.loc[:,('hotel_id','room_facilities')]
dados_tem_ar['tem_ar'] = dados_tem_ar['room_facilities'].apply(tem_recurso)
dados_tem_ar_media = dados_tem_ar.loc[:,('hotel_id','tem_ar')]
dados_tem_ar_media.drop_duplicates(inplace=True)

dados_hotel_nota.dropna(inplace=True)
dados_ar_nota = pd.merge(dados_tem_ar_media,dados_hotel_nota,on='hotel_id')
dados_ar_nota.loc[:,('tem_ar','Total')].groupby('tem_ar').mean()
# Out:
#            Total
# tem_ar
# False   8.375000
# True    8.459779

# %%
#E agora testando com recursos especificos(Vista do mar)
def tem_recurso(lista_string):
    lista = ast.literal_eval(lista_string)
    if 'Vista do mar'in lista:
        return True
    else:
        return False

dados_tem_vista = dados_details.loc[:,('hotel_id','room_facilities')]
dados_tem_vista['tem_vista'] = dados_tem_vista['room_facilities'].apply(tem_recurso)
dados_tem_vista_media = dados_tem_vista.loc[:,('hotel_id','tem_vista')]
dados_tem_vista_media.drop_duplicates(inplace=True)

dados_hotel_nota.dropna(inplace=True)
dados_vista_nota = pd.merge(dados_tem_vista_media,dados_hotel_nota,on='hotel_id')
dados_vista_nota.loc[:,('tem_vista','Total')].groupby('tem_vista').mean()
# Out:
#               Total
# tem_vista
# False      8.474419
# True       8.218750

# %% [markdown]
# Análise 7 - Existe alguma relação entre a nota recebida e a localização?

# %%
#Para vizualizaçao disso vamos fazer a media de nota de cada cidade e depois disso plotar um mapa

dados_hotel_nota = dados_ratings.loc[:,('hotel_id','Total')]
dados_nota_cidade = pd.merge(dados_hotel_nota,dados_hotel_cidade,on='hotel_id')
dados_nota_media_por_cidade = dados_nota_cidade.loc[:,('city_name','Total')].groupby('city_name').mean().reset_index()
dados_nota_media_por_cidade.dropna(inplace=True)
dados_nota_media_por_cidade
# Out:
#              city_name      Total
# 0       Angra dos Reis  10.000000
# 1           Anitápolis   9.400000
# 3   Balneário Camboriú   8.150000
# 5            Bombinhas   8.863636
# 6             Brasília  10.000000
# 8            Cabo Frio   9.500000
# 10            Camboriú   1.000000
# 11    Campos do Jordão   8.700000
# 12              Canela   9.000000
# 13       Florianópolis   8.373430
# 14            Garopaba   9.500000
# 15             Goiânia   8.562500
# 16             Gramado   7.416667
# 18              Ilhéus  10.000000
# 20              Itajaí   9.083333
# 21             Itapema   9.375000
# 24          Petrópolis   9.500000
# 26        Porto Alegre   7.600000
# 27          Porto Belo   9.766667
# 29     Poços de Caldas   8.333333
# 32            São José   9.500000
# 35             Ubatuba   8.000000
# 36             Urubici   4.000000

# %%
#configurar o geolocalizador sem verificação SSL
geolocator = Nominatim(user_agent="my_geocoder", ssl_context=None)

#função para mapear a nota para uma cor
def map_nota_to_color(nota):
    if 0 <= nota < 3:
        return 'red'
    elif 3 <= nota < 7:
        return 'orange'
    elif 7 <= nota < 9:
        return 'green'
    else:
        return 'purple'

#criar um mapa básico centrado em uma localização do brasil
mapa = folium.Map(location=[-15.7801, -47.9292], zoom_start=4)

#adicionar marcadores ao mapa
for index, row in dados_nota_media_por_cidade.iterrows():
    #manipular o nome da cidade antes de fazer a pesquisa
    formatted_city_name = format_city_name(row['city_name'])

    #obter as coordenadas a partir do nome da cidade
    location = geolocator.geocode(formatted_city_name, timeout=10)

    #verificar se a localização foi encontrada
    if location:
        # Mapear a nota para a cor do ícone
        color = map_nota_to_color(row['Total'])

        #criar marcador com popup contendo informações e cor ajustada
        folium.Marker(
            location=[location.latitude, location.longitude],
            popup=f"{row['city_name']}: {row['Total']}",
            icon=folium.Icon(color=color, icon='home')
        ).add_to(mapa)

#exibir o mapa no notebook
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e34199c7e343612d2ba46cab8e3a95c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e34199c7e343612d2ba46cab8e3a95c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e34199c7e343612d2ba46cab8e3a95c6 = L.map(
#                 &quot;map_e34199c7e343612d2ba46cab8e3a95c6&quot;,
#                 {
#                     center: [-15.7801, -47.9292],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_798466dabfff546a16a3abb7199ffdf3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e34199c7e343612d2ba46cab8e3a95c6);
#
#
#             var marker_320a8a5088c2844480006178ab84321a = L.marker(
#                 [-23.0063966, -44.316326],
#                 {}
#             ).addTo(map_e34199c7e343612d2ba46cab8e3a95c6);
#
#
#             var icon_b782a7463fe25f74878d9fbc374a79df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_320a8a5088c2844480006178ab84321a.setIcon(icon_b782a7463fe25f74878d9fbc374a79df);
#
#
#         var popup_87ba3d9e7f4575329bc7467d95c4ab5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7713948dbe650c5546842a18bfbd0f49 = $(`&lt;div id=&quot;html_7713948dbe650c5546842a18bfbd0f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angra dos Reis: 10.0&lt;/div&gt;`)[0];
#                 popup_87ba3d9e7f4575329bc7467d95c4ab5e.setContent(html_7713948dbe650c5546842a18bfbd0f49);
#
#
#
#         marker_320a8a5088c2844480006178ab84321a.bindPopup(popup_87ba3d9e7f4575329bc7467d95c4ab5e)
#         ;
#
#
#
#
#             var marker_ac9733c2d759cdc4b5e531e9b639574e = L.marker(
#                 [-27.9041185, -49.1287395],
#                 {}
#             ).addTo(map_e34199c7e343612d2ba46cab8e3a95c6);
#
#
#             var icon_d624934908dea5002c2e661bc4a7b854 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ac9733c2d759cdc4b5e531e9b639574e.setIcon(icon_d624934908dea5002c2e661bc4a7b854);
#
#
#         var popup_7239fc140e7c253c9e62fb183ee67b46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfeccd7ecd257f455cd4ecb2af2b5188 = $(`&lt;div id=&quot;html_dfeccd7ecd257f455cd4ecb2af2b5188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anitápolis: 9.4&lt;/div&gt;`)[0];
#                 popup_7239fc140e7c253c9e62fb183ee67b46.setContent(html_dfeccd7ecd257f455cd4ecb2af2b5188);
#
#
#
#         marker_ac9733c2d759cdc4b5e531e9b639574e.bindPopup(popup_7239fc140e7c253c9e62fb183ee67b46)
#         ;
#
#
#
#
#             var marker_8b7afcc3d802b8819ac05d26234919a8 = L.marker(
#                 [-26.9924395, -48.6339782],
#                 {}
#             ).addTo(map_e34199c7e343612d2ba46cab8e3a95c6);
#
#
#             var icon_387e60bdab14fd49793496daa083d48c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b7afcc3d802b8819ac05d26234919a8.setIcon(icon_387e60bdab14fd49793496daa083d48c);
#
#
#         var popup_6eb1bbf88b6984ff4831b7c909a521c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e8089088b953d2666176aca2089e4a9 = $(`&lt;div id=&quot;html_2e8089088b953d2666176aca2089e4a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Balneário Camboriú: 8.149999999999999&lt;/div&gt;`)[0];
#                 popup_6eb1bbf88b6984ff4831b7c909a521c4.setContent(html_2e8089088b953d2666176aca2089e4a9);
#
#
#
#         marker_8b7afcc3d802b8819ac05d26234919a8.bindPopup(popup_6eb1bbf88b6984ff4831b7c909a521c4)
#         ;
#
#
#
#
#             var marker_961a218d22e6dd72f770466d8074d363 = L.marker(
#                 [-27.1519159, -48.4875691],
#                 {}
#             ).addTo(map_e34199c7e343612d2ba46cab8e3a95c6);
#
#
#             var icon_42752b7cff41e2c52bf2bda0b60631cd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-

# %% [markdown]
# Análise 8 - Conclusão sobre as notas dos imóveis

# %% [markdown]
# - De acordo com as analises anteriores podemos inferir:
#
# - Imovéis localizados em cidades que possuem praia costumam fazer mais sucesso entre os demais.
#
# - A quantidade de recursos disponiveis não necessariamente impacta sobre a nota,o que impacta de verdade é a qualidade e experiencia que o cliente vivenciouao utilizar algum desses recursos.
#
# - Imovéis localizados em cidades que possuem praia costumam fazer mais sucesso entre os demais.
#
# - A localização do imóvel importa muito na sua avaliação, já que também faz parte da experiencia do cliente.

# %% [markdown]
# Análise 9 - Anúncios críticos

# %% [markdown]
# - Todos os anúncios sem avaliação : anúncios sem avaliação deixam o cliente com um certo receio de ir para aquele local, já que ele não possui nenhuma referência daquele hotel.
#
# - Anúncios com poucas avaliações e notas abaixo de 7: ainda com o mesmo motivo da passada, só que em uma situação mais complicada, porque além de possuir poucas opiniões, eles ainda são negativas,o que causa total receio por parte do cliente.
